# %%
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pickled_file = '../figures/2023-03-30/1/EET_hp-EET.pickle'

with open(pickled_file,'rb') as file:
    fig = pickle.load(file)

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
fig.axes
# Out:
# [<AxesSubplot:title={'center':'(a) Fear condititioning'}, ylabel='% Freezing'>,
#  <AxesSubplot:title={'center':'(b) Fear recall'}>,
#  <AxesSubplot:title={'center':'(c) Extinction Day 1'}>,
#  <AxesSubplot:title={'center':'(d) Extinction Day 2'}>,
#  <AxesSubplot:title={'center':'(e) Retention'}>,
#  <AxesSubplot:title={'center':'(f) Spont. Rec.'}>]

# %%
# gives y loc of each point
cfrt_data = fig.axes[1].lines[0].get_data()
cfrt_data
